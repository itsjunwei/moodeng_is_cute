# %%
import torch

# %%
ckpt = torch.load("last.ckpt", weights_only=False)
ckpt
# Out:
# {'epoch': 149,
#  'global_step': 4200,
#  'pytorch-lightning_version': '2.4.0',
#  'state_dict': OrderedDict([('mel.0.kernel',
#                tensor([[[-0.0000, -0.0001, -0.0003,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        ...,
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0012, -0.0000, -0.0000]]],
#                       device='cuda:0')),
#               ('mel.1.spectrogram.window',
#                tensor([0.0000e+00, 1.0431e-06, 4.1723e-06,  ..., 9.4175e-06, 4.1723e-06,
#                        1.0431e-06], device='cuda:0')),
#               ('mel.1.mel_scale.fb',
# ...

# %%
f = torch.load("epoch=149-step=4200.ckpt", weights_only=False)
f
# Out:
# {'epoch': 149,
#  'global_step': 4200,
#  'pytorch-lightning_version': '2.4.0',
#  'state_dict': OrderedDict([('mel.0.kernel',
#                tensor([[[-0.0000, -0.0001, -0.0003,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        ...,
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000]],
#
#                        [[-0.0000, -0.0000, -0.0000,  ..., -0.0012, -0.0000, -0.0000]]],
#                       device='cuda:0')),
#               ('mel.1.spectrogram.window',
#                tensor([0.0000e+00, 1.0431e-06, 4.1723e-06,  ..., 9.4175e-06, 4.1723e-06,
#                        1.0431e-06], device='cuda:0')),
#               ('mel.1.mel_scale.fb',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 [t1 == t2 for t1, t2 in zip(ckpt.values(), f.values())]
#
# Cell In[13], line 1, in <listcomp>(.0)
# ----> 1 [t1 == t2 for t1, t2 in zip(ckpt.values(), f.values())]
#
# RuntimeError: Boolean value of Tensor with more than one value is ambiguous
